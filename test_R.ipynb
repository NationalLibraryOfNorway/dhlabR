# %% [markdown]
# # Example

# %%
library(devtools)
library(httr)
library(jsonlite)

# %%
load_all()
# Out:
# ℹ Loading dhlab-r

# %%
corpus = get_document_corpus()

# %%
corpus
# Out:
#   dhlabid   urn
# 0 100233518 URN:NBN:no-nb_digibok_2014102808008
# 1 100475655 URN:NBN:no-nb_digibok_2008111204042
# 2 100011141 URN:NBN:no-nb_digibok_2009021804079
# 3 100482436 URN:NBN:no-nb_digibok_2017110207002
# 4 100508038 URN:NBN:no-nb_digibok_2006081000055
# 5 100555146 URN:NBN:no-nb_digibok_2011112805063
# 6 100554013 URN:NBN:no-nb_digibok_2011112508028
# 7 100423155 URN:NBN:no-nb_digibok_2020101207508
# 8 100039137 URN:NBN:no-nb_digibok_2008082004072
# 9 100291102 URN:NBN:no-nb_digibok_2016041908034
#   title
# 0 Det gjelder ditt ekteskap
# 1 Kommunalteknikk : vann, avløp og renovasjon
# 2 Næringutvikling i utmark : strategisk plan
# 3 Det første Aarhundrede af den norske Hærs Historie
# 4 Dikte og sange : i utvalg
# 5 In vivo : roman
# 6 Gurigullet på hurtigtoget
# 7 Black Rabbit Hall
# 8 Jeg skal til Katnosa i kveld : fortellinger
# 9 Kraft til andre : grossist og agent i norsk elektrohandel: 1918-1968 EL grossistforeningen, norske elektrogrossister og agenter
#   authors                               oaiid
# 0 Johnsen , Gordon                      oai:nb.bibsys.no:998920186154702202
# 1 From , Jan Oddvar / From , Jan Oddvar oai:nb.bibsys.no:990116131304702202
# 2 Sundby , Andreas                      oai:nb.bibsys.no:990207657204702202
# 3 Schnitler , Didrik                    oai:nb.bibsys.no:999204305034702202
# 4 Bjørnson , Bjørnstjerne               oai:nb.bibsys.no:999419405604702202
# 5 Gulliksen , Geir / Syvertsen , Håvard oai:nb.bibsys.no:990418042444702202
# 6 Rongen , Bjørn / Moa , Vinni Okolow   oai:nb.bibsys.no:999509779424702202
# 7 Chase , Eve / Mehren , Hege           oai:nb.bibsys.no:999919818982702202
# 8 Wiese , Jan                           oai:nb.bibsys.no:999806242404702202
# 9 Lunde , Johs.                         oai:nb.bibsys.no:997512003954702202
#   sesamid                          isbn10     city   timestamp year
# 0 c7d928f78f85748e5c1a3961fa2cb0ef 8250308409 [Oslo] 19880101  1988
# 1 7295e87d31bb3e80e35619c89ce2e295 8205294895 [Oslo] 20010101  2001
# 2 4f73a1fc8e7e77054c917ee035912d53            Oslo   20020101  2002
# 3 f7a9714ed24dc7d4cb6c66597789baaf                   18740101  1874
# 4 bc5c90cd72066887290720e1aaf218e4            Oslo   19500101  1950
# 5 37ffa93848e3453bf15f3377024e2f53 8203188842 Oslo   20040101  2004
# 6 72755025476654c690648447c5b08ce2            Oslo   19540101  1954
# 7 06524a54fdedec419a6a4b4b0f38f151            [Oslo] 20160101  2016
# 8 40822a57ea655144d6b87041b89e42c2 8205253897 [Oslo] 19980101  1998
# 9 ebb0a318e4aadb2308795ca05733358a            Oslo   19690101  1969
#   publisher                                    langs
# 0 Ansgar                                       nob
# 1 Gyldendal yrkesopplæring                     mul / nob / nno
# 2 Statens nærings- og distriktsutviklingsfornd nob
# 3 Selskabet for Folkeoplysningens Fremme       nob
# 4 Gyldendal                                    nob
# 5 Aschehoug                                    nob
# 6 Damm                                         nob
# 7 Gyldendal                                    nob / eng
# 8 Gyldendal                                    nob
# 9 Foreningen                                   nob
#   subjects
# 0 ekteskap / kristen / etikk / psykologi / samliv
# 1 VAR-teknikk / kommunalteknikk / var-teknikk / vann / drikkevann / avløp / renovasjon
# 2 Utmarksnæring / Utmarksplanlegging / Industrietablering
# 3 Hæren / geografi/historie
# 4
# 5 norske / romaner / 2000-tallet
# 6
# 7
# 8
# 9
#   ddc     genres  literaryform     doctype ocr_creator ocr_timestamp
# 0 173             Faglitteratur    digibok nb          20060101
# 1 628             Faglitteratur    digibok nb          20060101
# 2                 Uklassifisert    digibok nb          20060101
# 3                 Faglitteratur    digibok nb          20060101
# 4                 Uklassifisert    digibok nb          20060101
# 5 839.823 novel   Skjønnlitteratur digibok nb          20060101
# 6                 Uklassifisert    digibok nb          20060101
# 7 823     novel   Skjønnlitteratur digibok nb          20060101
# 8 839.823 fiction Skjønnlitteratur digibok nb          20060101
# 9 381             Faglitteratur    digibok nb          20060101

# %%
freq = get_document_frequencies(unname(corpus$'urn'), cutoff = 0, words=list('.',','))

# %%
df <- as.data.frame(do.call(rbind, my_nested_list))

# %%
df
# Out:
#    V1        V2 V3    V4
# 1  100129497 .  7091  168346
# 2  100136651 .  77    2076
# 3  100129497 ,  10129 168346
# 4  100136651 ,  28    2076
# 5  100101639 .  260   5812
# 6  100101639 ,  102   5812
# 7  100160905 .  1345  23737
# 8  100168860 .  14007 217650
# 9  100179822 .  6119  100224
# 10 100160905 ,  921   23737
# 11 100168860 ,  11182 217650
# 12 100179822 ,  5608  100224
# 13 100256436 .  2601  43656
# 14 100256436 ,  1686  43656
# 15 100288149 .  2322  55772
# 16 100288149 ,  2141  55772
# 17 100306541 .  6784  103118
# 18 100306541 ,  5041  103118
# 19 100406251 .  418   5465
# 20 100406251 ,  132   5465

# %%
colnames(df) = c("dhlabid", "word", "freq", "tot_doc_f")

# %%
df
# Out:
#    id        pid fid   lid
# 1  100129497 .   7091  168346
# 2  100136651 .   77    2076
# 3  100129497 ,   10129 168346
# 4  100136651 ,   28    2076
# 5  100101639 .   260   5812
# 6  100101639 ,   102   5812
# 7  100160905 .   1345  23737
# 8  100168860 .   14007 217650
# 9  100179822 .   6119  100224
# 10 100160905 ,   921   23737
# 11 100168860 ,   11182 217650
# 12 100179822 ,   5608  100224
# 13 100256436 .   2601  43656
# 14 100256436 ,   1686  43656
# 15 100288149 .   2322  55772
# 16 100288149 ,   2141  55772
# 17 100306541 .   6784  103118
# 18 100306541 ,   5041  103118
# 19 100406251 .   418   5465
# 20 100406251 ,   132   5465
